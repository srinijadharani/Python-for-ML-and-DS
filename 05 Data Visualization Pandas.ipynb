# %% [markdown]
# # **Pandas Built-in Data Visualization**

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# %matplotlib inline

# %%
df1=pd.read_csv("df1", index_col=0)
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2=pd.read_csv("df2")
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df3=pd.read_csv("df3")
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %%
#to view the data present in column A in df1.
df1["A"].hist()
#this will actually call matplotlib under the hood.
#so we can add matplotlib arguments to pandas.

# %%
df1["A"].hist(bins=30, color="aqua")

# %%
df1["A"].plot(kind="hist", bins=30)

# %%
df1.plot(kind="hist", bins=40)

# %%
df1["A"].plot.hist()

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df2.plot.area()

# %%
df2.plot.bar()

# %%
df2.plot.bar(stacked=True, figsize=(10,3))

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1.plot.scatter(x="A", y="B")

# %%
df1.plot.scatter(x="A", y="B", c="C")

# %%
df1.plot.scatter(x="A", y="B", c="C", cmap="magma")

# %%
df1.plot.scatter(x="A", y="B", s=df1["C"]*20, c="D", cmap="coolwarm")

# %%
df2.plot.box()

# %%
df=pd.DataFrame(np.random.randn(1000,2), columns=["a","b"])

# %%
df.head()
# Out:
#           a         b
# 0 -0.526201 -0.985189
# 1  0.889791  1.026462
# 2 -0.748428 -0.196130
# 3  2.328809  0.532477
# 4  1.823828  0.047679

# %%
df.plot.hexbin(x="a", y="b", gridsize=20, cmap="magma")
#the hexagonal bins get darker as there are more points in there

# %%
df2
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008
# 5  0.286043  0.593465  0.907307  0.637898
# 6  0.430436  0.166230  0.469383  0.497701
# 7  0.312296  0.502823  0.806609  0.850519
# 8  0.187765  0.997075  0.895955  0.530390
# 9  0.908162  0.232726  0.414138  0.432007

# %%
df2["a"].plot.kde()

# %%
df2.plot.kde()

# %%
df2.plot.density()

# %%
df2["b"].plot.density()
